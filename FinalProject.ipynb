# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
train_features = train_df[["CreditScore","Age","Tenure","Balance","EstimatedSalary","Point Earned"]]

train_labels = train_df["Exited"]

train_features.head()
train_labels.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
mlp_classifier = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(8, 2), random_state=11,max_iter=10000)

mlp_classifier.fit(train_features.to_numpy(),train_labels.to_numpy())
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# MLPClassifier(alpha=1e-05, hidden_layer_sizes=(8, 2), max_iter=10000,
#               random_state=11, solver='lbfgs')

# %%
test_df = pd.read_csv("test.csv")

test_inputs = test_df[["CreditScore", "Age", "Tenure", "Balance", "EstimatedSalary", "Point Earned"]]
y_actual = test_df["Exited"]

y_predicted_mlp = mlp_classifier.predict(test_inputs.to_numpy())

mlp_accuracy_score = accuracy_score(y_predicted_mlp, y_actual)

conf_matrix = confusion_matrix(y_actual, y_predicted_mlp)

print(f"Accuracy of the MLP Classifier = {mlp_accuracy_score}")
print("\nConfusion Matrix:")
print(conf_matrix)


plt.figure(figsize=(4, 3))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy of the MLP Classifier = 0.8014354066985646
#
# Confusion Matrix:
# [[4020    0]
#  [ 996    0]]

# %%
CreditScore = float(input("Enter Credit Score: "))
Age = float(input("Enter Age: "))
Tenure = float(input("Enter Tenure: "))
Balance = float(input("Enter Balance: "))
EstimatedSalary = float(input("Enter Estimated Salary: "))
PointEarned = float(input("Enter Points Earned: "))

new_inputs = np.array([[CreditScore, Age, Tenure, Balance, EstimatedSalary, PointEarned]])

predictions = mlp_classifier.predict(new_inputs)

if predictions[0]==1:
    print ("The person is likely to churn")
if predictions[0]==0:
    print ("The person is unlikely to churn")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/brandoncheung/Desktop/I310D/Final Project/FinalProject.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/brandoncheung/Desktop/I310D/Final%20Project/FinalProject.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> CreditScore = float(input("Enter Credit Score: "))
#       <a href='vscode-notebook-cell:/Users/brandoncheung/Desktop/I310D/Final%20Project/FinalProject.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> Age = float(input("Enter Age: "))
#       <a href='vscode-notebook-cell:/Users/brandoncheung/Desktop/I310D/Final%20Project/FinalProject.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> Tenure = float(input("Enter Tenure: "))
#
# ValueError: could not convert string to float: ''

# %%
df = pd.read_csv("Dataset.csv")
sns.distplot(df['CreditScore'][df.Exited==0])
sns.distplot(df['CreditScore'][df.Exited==1])
plt.legend(['Exited=0','Exited=1'])
plt.title('Number of Bank Customers by Credit Score and Exit Status')
# Out:
# /var/folders/gg/brcqhwks3l5_byjdghsnlcvr0000gn/T/ipykernel_76742/2566296409.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CreditScore'][df.Exited==0])
# /var/folders/gg/brcqhwks3l5_byjdghsnlcvr0000gn/T/ipykernel_76742/2566296409.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.distplot(df['Balance'][df.Exited==0])
sns.distplot(df['Balance'][df.Exited==1])
plt.legend(['Exited=0','Exited=1'])
plt.title('Number of Bank Customers by Account Balance and Exit Status')
# Out:
# /var/folders/gg/brcqhwks3l5_byjdghsnlcvr0000gn/T/ipykernel_43848/3823624715.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Balance'][df.Exited==0])
# /var/folders/gg/brcqhwks3l5_byjdghsnlcvr0000gn/T/ipykernel_43848/3823624715.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.distplot(df['EstimatedSalary'][df.Exited==0])
sns.distplot(df['EstimatedSalary'][df.Exited==1])
plt.legend(['Exited=0','Exited=1'])
plt.title('Number of Bank Customers by Estimated Salary and Exit Status')
# Out:
# /var/folders/gg/brcqhwks3l5_byjdghsnlcvr0000gn/T/ipykernel_43848/4157121377.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['EstimatedSalary'][df.Exited==0])
# /var/folders/gg/brcqhwks3l5_byjdghsnlcvr0000gn/T/ipykernel_43848/4157121377.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.distplot(df['Point Earned'][df.Exited==0])
sns.distplot(df['Point Earned'][df.Exited==1])
plt.legend(['Exited=0','Exited=1'])
plt.title('Number of Bank Customers by Points Earned and Exit Status')
# Out:
# /var/folders/gg/brcqhwks3l5_byjdghsnlcvr0000gn/T/ipykernel_43848/2777501866.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Point Earned'][df.Exited==0])
# /var/folders/gg/brcqhwks3l5_byjdghsnlcvr0000gn/T/ipykernel_43848/2777501866.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.distplot(df['Age'][df.Exited==0])
sns.distplot(df['Age'][df.Exited==1])
plt.legend(['Exited=0','Exited=1'])
plt.title('Number of Bank Customers by Age and Exit Status')
# Out:
# /var/folders/gg/brcqhwks3l5_byjdghsnlcvr0000gn/T/ipykernel_43848/1674645019.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'][df.Exited==0])
# /var/folders/gg/brcqhwks3l5_byjdghsnlcvr0000gn/T/ipykernel_43848/1674645019.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# ...

# %%
sns.distplot(df['Tenure'][df.Exited==0])
sns.distplot(df['Tenure'][df.Exited==1])
plt.legend(['Exited=0','Exited=1'])
plt.title('Number of Bank Customers by Tenure and Exit Status')
# Out:
# /var/folders/gg/brcqhwks3l5_byjdghsnlcvr0000gn/T/ipykernel_43848/715597340.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Tenure'][df.Exited==0])
# /var/folders/gg/brcqhwks3l5_byjdghsnlcvr0000gn/T/ipykernel_43848/715597340.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...
